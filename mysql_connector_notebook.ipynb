# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

# %%
import pandas as pd
con=mysql.connector.connect(
    host='127.0.0.1',
    port='3306',
    user='root',
    password='vinodhini',
    database='world')

#https://pandas.pydata.ord/pandas-docs/version/0.23.4/generated/pandas.read_sql_query.html

df=pd.read_sql_query("Select * from country",con)
df
# Out:
#     Code          Name      Continent                     Region  SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean        193.0
# 1    AFG   Afghanistan           Asia  Southern and Central Asia     652090.0
# 2    AGO        Angola         Africa             Central Africa    1246700.0
# 3    AIA      Anguilla  North America                  Caribbean         96.0
# 4    ALB       Albania         Europe            Southern Europe      28748.0
# ..   ...           ...            ...                        ...          ...
# 234  YEM         Yemen           Asia                Middle East     527968.0
# 235  YUG    Yugoslavia         Europe            Southern Europe     102173.0
# 236  ZAF  South Africa         Africa            Southern Africa    1221037.0
# 237  ZMB        Zambia         Africa             Eastern Africa     752618.0
# 238  ZWE      Zimbabwe         Africa             Eastern Africa     390757.0
#
# ...

# %%
df.head(5)
# Out:
#   Code         Name      Continent                     Region  SurfaceArea  \
# 0  ABW        Aruba  North America                  Caribbean        193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia     652090.0
# 2  AGO       Angola         Africa             Central Africa    1246700.0
# 3  AIA     Anguilla  North America                  Caribbean         96.0
# 4  ALB      Albania         Europe            Southern Europe      28748.0
#
#    IndepYear  Population  LifeExpectancy     GNP  GNPOld  \
# 0        NaN      103000            78.4   828.0   793.0
# 1     1919.0    22720000            45.9  5976.0     NaN
# 2     1975.0    12878000            38.3  6648.0  7984.0
# 3        NaN        8000            76.1    63.2     NaN
# 4     1912.0     3401200            71.6  3205.0  2500.0
#
#                LocalName                                GovernmentForm  \
# 0                  Aruba  Nonmetropolitan Territory of The Netherlands
# ...

# %%
df.tail()
# Out:
#     Code          Name Continent           Region  SurfaceArea  IndepYear  \
# 234  YEM         Yemen      Asia      Middle East     527968.0     1918.0
# 235  YUG    Yugoslavia    Europe  Southern Europe     102173.0     1918.0
# 236  ZAF  South Africa    Africa  Southern Africa    1221037.0     1910.0
# 237  ZMB        Zambia    Africa   Eastern Africa     752618.0     1964.0
# 238  ZWE      Zimbabwe    Africa   Eastern Africa     390757.0     1980.0
#
#      Population  LifeExpectancy       GNP    GNPOld     LocalName  \
# 234    18112000            59.8    6041.0    5729.0      Al-Yaman
# 235    10640000            72.4   17000.0       NaN   Jugoslavija
# 236    40377000            51.1  116729.0  129092.0  South Africa
# 237     9169000            37.2    3377.0    3922.0        Zambia
# 238    11669000            37.8    5951.0    8670.0      Zimbabwe
#
#        GovernmentForm          HeadOfState  Capital Code2
# 234          Republic   Ali Abdallah Salih   1780.0    YE
# ...

# %%
def Q(sql):
    res=pd.read_sql_query(sql,con)
    return(res)

# %%
res=Q("select * from country")
res
# Out:
#     Code          Name      Continent                     Region  SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean        193.0
# 1    AFG   Afghanistan           Asia  Southern and Central Asia     652090.0
# 2    AGO        Angola         Africa             Central Africa    1246700.0
# 3    AIA      Anguilla  North America                  Caribbean         96.0
# 4    ALB       Albania         Europe            Southern Europe      28748.0
# ..   ...           ...            ...                        ...          ...
# 234  YEM         Yemen           Asia                Middle East     527968.0
# 235  YUG    Yugoslavia         Europe            Southern Europe     102173.0
# 236  ZAF  South Africa         Africa            Southern Africa    1221037.0
# 237  ZMB        Zambia         Africa             Eastern Africa     752618.0
# 238  ZWE      Zimbabwe         Africa             Eastern Africa     390757.0
#
# ...

# %%
res=Q("select * from country where name like 'An%'")
res
# Out:
#   Code                 Name      Continent           Region  SurfaceArea  \
# 0  AGO               Angola         Africa   Central Africa    1246700.0
# 1  AIA             Anguilla  North America        Caribbean         96.0
# 2  AND              Andorra         Europe  Southern Europe        468.0
# 3  ATA           Antarctica     Antarctica       Antarctica   13120000.0
# 4  ATG  Antigua and Barbuda  North America        Caribbean        442.0
#
#    IndepYear  Population  LifeExpectancy     GNP  GNPOld            LocalName  \
# 0     1975.0    12878000            38.3  6648.0  7984.0               Angola
# 1        NaN        8000            76.1    63.2     NaN             Anguilla
# 2     1278.0       78000            83.5  1630.0     NaN              Andorra
# 3        NaN           0             NaN     0.0     NaN                   Â–
# 4     1981.0       68000            70.5   612.0   584.0  Antigua and Barbuda
#
# ...

# %%
res.columns
# Out:
# Index(['Code', 'Name', 'Continent', 'Region', 'SurfaceArea', 'IndepYear',
#        'Population', 'LifeExpectancy', 'GNP', 'GNPOld', 'LocalName',
#        'GovernmentForm', 'HeadOfState', 'Capital', 'Code2'],
#       dtype='object')

# %%
res=Q("select count(code) from country")
res
# Out:
#    count(code)
# 0          239

# %%
res=Q('select distinct(continent) from country')
res
# Out:
#        continent
# 0  North America
# 1           Asia
# 2         Africa
# 3         Europe
# 4  South America
# 5        Oceania
# 6     Antarctica

# %%
res=Q('select capital,continent from country group by continent')
res
# Out:
#    capital      continent
# 0    129.0  North America
# 1      1.0           Asia
# 2     56.0         Africa
# 3     34.0         Europe
# 4     69.0  South America
# 5     54.0        Oceania
# 6      NaN     Antarctica

# %%
res=Q('Select count(population),continent from country group by continent')
res
# Out:
#    count(population)      continent
# 0                 37  North America
# 1                 51           Asia
# 2                 58         Africa
# 3                 46         Europe
# 4                 14  South America
# 5                 28        Oceania
# 6                  5     Antarctica

# %%
res=Q('select count(governmentform) from country')
res
# Out:
#    count(governmentform)
# 0                    239

# %%
res=Q('select avg(population) from country')
res
# Out:
#    avg(population)
# 0     2.543410e+07

# %%
res=Q('select sum(population) from country')
res
# Out:
#    sum(population)
# 0     6.078749e+09

# %%
res=Q('select count(governmentform),continent from country group by continent')
res
# Out:
#    count(governmentform)      continent
# 0                     37  North America
# 1                     51           Asia
# 2                     58         Africa
# 3                     46         Europe
# 4                     14  South America
# 5                     28        Oceania
# 6                      5     Antarctica

# %%
res=Q('select count(governmentform),continent,code2 from country group by continent order by code2')
res
# Out:
#    count(governmentform)      continent code2
# 0                     51           Asia    AF
# 1                     46         Europe    AL
# 2                     58         Africa    AO
# 3                      5     Antarctica    AQ
# 4                     14  South America    AR
# 5                     28        Oceania    AS
# 6                     37  North America    AW

# %%
con.close;
